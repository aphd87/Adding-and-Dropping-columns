# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
transactions = pd.read_excel("grocery_database.xlsx", sheet_name = "transactions")
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
transactions
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  sales_cost
# 0              7       19.16
# 1              5        7.71
# 2              4       26.97
# ...

# %%
#New column
transactions["store_id"]=1 #All observations have 1

# %%
transactions
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  sales_cost  store_id
# 0              7       19.16         1
# 1              5        7.71         1
# ...

# %%
#Profit column
transactions["profit"] = transactions["sales_cost"]*0.2

# %%
transactions
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  sales_cost  store_id  profit
# 0              7       19.16         1   3.832
# ...

# %%
transactions["sales_type"] = np.where(transactions["sales_cost"] > 20, "Large", "Small")
#Apply a where statement
#Where sales cost are greater than 20 should be Large, otherwise Small

# %%
transactions
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  sales_cost  store_id  profit sales_type
# 0              7       19.16         1   3.832      Small
# ...

# %%
#Select funcitonality
#List of conditions that we want to apply
condition_rules = [transactions["sales_cost"]>50, transactions["sales_cost"]>20, transactions["sales_cost"]>10]
#Outcomes associated with this list
outcomes = ["X-Large", "Large","Medium"]
#Now combine both
transactions["sales_type"] = np.select(condition_rules, outcomes, default = "Small") #Small applies to anything that has not been labeled already

# %%
transactions
#We can see medium, small, and large here.
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  sales_cost  store_id  profit sales_type
# 0              7       19.16         1   3.832     Medium
# ...

# %%
#Remove columns
new_df = transactions.drop(["sales_cost"], axis=1) #axis=1 drops a column, for rows use 0

# %%
new_df
# Out:
#        customer_id transaction_date  transaction_id  product_area_id  \
# 0                1       2020-04-10    435657533999                3
# 1                1       2020-04-10    435657533999                2
# 2                1       2020-06-02    436189770685                4
# 3                1       2020-06-02    436189770685                1
# 4                1       2020-06-10    436265380298                4
# ...            ...              ...             ...              ...
# 38501          870       2020-09-23    437316479610                5
# 38502          870       2020-09-23    437316479610                2
# 38503          870       2020-09-30    437385547544                5
# 38504          870       2020-09-30    437385547544                1
# 38505          870       2020-09-30    437385547544                2
#
#        num_items  store_id  profit sales_type
# 0              7         1   3.832     Medium
# ...
